# %%
import pandas as pd

df = pd.read_csv("scraping-project.csv")
df.head()
# Out:
#   platform           listing_id                title      city bedrooms  \
# 0   airbnb  1474375658014894640    Cabin in Mayrouba  Mayrouba        2
# 1   airbnb  1542196639719322486       Villa in Faqra     Faqra        3
# 2   airbnb  1526620901894322208  Apartment in Beirut    Beirut        1
# 3   airbnb  1200706754310956282    Cabin in Chabtine  Chabtine        1
# 4   airbnb  1393555511912612853  Apartment in Beirut    Beirut        1
#
#   bathrooms  price  rating review_count amenities_count      last_scraped
# 0         1  108.6    5.00           16              31  19/11/2025 11:35
# 1         2  341.4    5.00            3              37  19/11/2025 11:35
# 2         1   43.2    5.00            3              22  19/11/2025 11:35
# 3         1  114.2    4.97           65              20  19/11/2025 11:35
# 4         1   63.6    4.97           32              37  19/11/2025 11:35

# %%
print(f"Shape of DataFrame before dropping duplicates: {df.shape}")

df = df.sort_values(by='review_count', ascending=False).drop_duplicates(subset=['title', 'price', 'amenities_count', 'bedrooms', 'bathrooms'], keep='first')

print(f"Shape of DataFrame after dropping duplicates: {df.shape}")
df.head()
# Out:
# Shape of DataFrame before dropping duplicates: (1863, 11)
# Shape of DataFrame after dropping duplicates: (1391, 11)
#      platform listing_id                           title  \
# 99     airbnb   51726083             Apartment in Beirut
# 1149  Stayinn        132  Amine 601, 1-BR in Mar Mikhael
# 848   Stayinn        131  Amine 601, 1-BR in Mar Mikhael
# 400   Stayinn        131  Amine 601, 1-BR in Mar Mikhael
# 700   Stayinn        133  Amine 601, 1-BR in Mar Mikhael
#
#                                                    city   bedrooms  \
# 99                                               Beirut        NaN
# 1149  Apartment 50 sq. m in Armenia, Beirut, Beirut ...  1 bedroom
# 848   Apartment 50 sq. m in Armenia, Beirut, Beirut ...  1 bedroom
# 400   Apartment 50 sq. m in Armenia, Beirut, Beirut ...  1 bedroom
# 700   Apartment 50 sq. m in Armenia, Beirut, Beirut ...  1 bedroom
#
#        bathrooms        price  rating review_count        amenities_count  \
# 99             1           35    4.75           99                     37
# 1149  1 bathroom  $92 / night    5.00   98 reviews  Show All 43 Amenities
# 848   1 bathroom  $91 / night    5.00   98 reviews  Show All 43 Amenities
# 400   1 bathroom  $94 / night    5.00   98 reviews  Show All 43 Amenities
# 700   1 bathroom  $93 / night    5.00   98 reviews  Show All 43 Amenities
#
#                     last_scraped
# 99              19/11/2025 11:39
# 1149  2025-11-24T06:34:34.893310
# 848   2025-11-22T06:30:40.175210
# 400   2025-11-19T14:27:06.724146
# 700   2025-11-21T06:34:34.844513

# %%
df.drop(columns=['listing_id'], inplace=True)
df.head()
# Out:
#      platform                           title  \
# 99     airbnb             Apartment in Beirut
# 1149  Stayinn  Amine 601, 1-BR in Mar Mikhael
# 848   Stayinn  Amine 601, 1-BR in Mar Mikhael
# 400   Stayinn  Amine 601, 1-BR in Mar Mikhael
# 700   Stayinn  Amine 601, 1-BR in Mar Mikhael
#
#                                                    city   bedrooms  \
# 99                                               Beirut        NaN
# 1149  Apartment 50 sq. m in Armenia, Beirut, Beirut ...  1 bedroom
# 848   Apartment 50 sq. m in Armenia, Beirut, Beirut ...  1 bedroom
# 400   Apartment 50 sq. m in Armenia, Beirut, Beirut ...  1 bedroom
# 700   Apartment 50 sq. m in Armenia, Beirut, Beirut ...  1 bedroom
#
#        bathrooms        price  rating review_count        amenities_count  \
# 99             1           35    4.75           99                     37
# 1149  1 bathroom  $92 / night    5.00   98 reviews  Show All 43 Amenities
# 848   1 bathroom  $91 / night    5.00   98 reviews  Show All 43 Amenities
# 400   1 bathroom  $94 / night    5.00   98 reviews  Show All 43 Amenities
# 700   1 bathroom  $93 / night    5.00   98 reviews  Show All 43 Amenities
#
#                     last_scraped
# 99              19/11/2025 11:39
# 1149  2025-11-24T06:34:34.893310
# 848   2025-11-22T06:30:40.175210
# 400   2025-11-19T14:27:06.724146
# 700   2025-11-21T06:34:34.844513

# %%
print(f"Shape of DataFrame before dropping rows with excessive missing values: {df.shape}")

missing_values_per_row = df.isnull().sum(axis=1)

df = df[missing_values_per_row <= 3]

print(f"Shape of DataFrame after dropping rows with excessive missing values: {df.shape}")
# Out:
# Shape of DataFrame before dropping rows with excessive missing values: (1391, 10)
# Shape of DataFrame after dropping rows with excessive missing values: (1362, 10)

# %%
print("DataFrame info before type conversion and imputation:")
df.info()

# Columns to convert to numeric
numeric_cols_to_convert = ['bedrooms', 'bathrooms', 'price', 'review_count', 'amenities_count']

# String cleaning for specific columns before converting to numeric
# Ensure the column is treated as string, handle potential NaN values.

df['bedrooms'] = df['bedrooms'].astype(str).str.replace(r' bedroom(s)?', '', regex=True)
df['bathrooms'] = df['bathrooms'].astype(str).str.replace(r' bathroom(s)?', '', regex=True)
df['price'] = df['price'].astype(str).str.replace(r'[$,/night]', '', regex=True)
df['review_count'] = df['review_count'].astype(str).str.replace(r' reviews', '', regex=True)
df['amenities_count'] = df['amenities_count'].astype(str).str.replace(r'Show All | Amenities', '', regex=True)

for col in numeric_cols_to_convert:
    df[col] = pd.to_numeric(df[col], errors='coerce')

for col in numeric_cols_to_convert:
    if df[col].isnull().any():
        df[col] = df[col].fillna(df[col].mean())

if df['rating'].isnull().any():
    df['rating'] = df['rating'].fillna(df['rating'].mean())

int_cols_to_convert = ['bedrooms', 'bathrooms', 'review_count', 'amenities_count']
for col in int_cols_to_convert:
    df[col] = df[col].astype(int)

print("\nDataFrame info after type conversion and imputation:")
df.info()
df.head()
# Out:
# DataFrame info before type conversion and imputation:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1362 entries, 99 to 266
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   platform         1362 non-null   object
#  1   title            1362 non-null   object
#  2   city             1357 non-null   object
#  3   bedrooms         1273 non-null   object
#  4   bathrooms        1168 non-null   object
#  5   price            1295 non-null   object
#  6   rating           685 non-null    float64
#  7   review_count     1338 non-null   object
#  8   amenities_count  1362 non-null   object
#  9   last_scraped     1362 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 117.0+ KB
#
# DataFrame info after type conversion and imputation:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1362 entries, 99 to 266
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   platform         1362 non-null   object
#  1   title            1362 non-null   object
#  2   city             1357 non-null   object
#  3   bedrooms         1362 non-null   int64
#  4   bathrooms        1362 non-null   int64
#  5   price            1362 non-null   float64
#  6   rating           1362 non-null   float64
#  7   review_count     1362 non-null   int64
#  8   amenities_count  1362 non-null   int64
#  9   last_scraped     1362 non-null   object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 117.0+ KB
#      platform                           title  \
# 99     airbnb             Apartment in Beirut
# 1149  Stayinn  Amine 601, 1-BR in Mar Mikhael
# 848   Stayinn  Amine 601, 1-BR in Mar Mikhael
# 400   Stayinn  Amine 601, 1-BR in Mar Mikhael
# 700   Stayinn  Amine 601, 1-BR in Mar Mikhael
#
#                                                    city  bedrooms  bathrooms  \
# 99                                               Beirut         1          1
# 1149  Apartment 50 sq. m in Armenia, Beirut, Beirut ...         1          1
# 848   Apartment 50 sq. m in Armenia, Beirut, Beirut ...         1          1
# 400   Apartment 50 sq. m in Armenia, Beirut, Beirut ...         1          1
# 700   Apartment 50 sq. m in Armenia, Beirut, Beirut ...         1          1
#
#       price  rating  review_count  amenities_count                last_scraped
# 99     35.0    4.75            99               37            19/11/2025 11:39
# 1149   92.0    5.00            98               43  2025-11-24T06:34:34.893310
# 848    91.0    5.00            98               43  2025-11-22T06:30:40.175210
# 400    94.0    5.00            98               43  2025-11-19T14:27:06.724146
# 700    93.0    5.00            98               43  2025-11-21T06:34:34.844513

# %%
print("Unique cities before standardization:")
print(df['city'].value_counts().head(20))

def standardize_city_names(city_name):
    if pd.isna(city_name):
        return city_name
    city = str(city_name).strip().lower()

    # Specific standardizations
    if 'batroun' in city:
        return 'Batroun'
    if 'beirut' in city:
        return 'Beirut'
    if 'achrafieh' in city or 'ashrafieh' in city:
        return 'Achrafieh'
    if 'mayrouba' in city:
        return 'Mayrouba'
    if 'faqra' in city:
        return 'Faqra'
    if 'chabtine' in city:
        return 'Chabtine'
    if 'jounieh' in city:
        return 'Jounieh'
    if 'byblos' in city or 'jbeil' in city:
        return 'Byblos'
    if 'harissa' in city:
        return 'Harissa'
    if 'zouk mosbeh' in city:
        return 'Zouk Mosbeh'
    if 'rabieh' in city:
        return 'Rabieh'
    if 'baabda' in city:
        return 'Baabda'
    if 'byblos' in city:
        return 'Byblos'
    if 'jeita' in city:
        return 'Jeita'
    if 'ghosta' in city:
        return 'Ghosta'
    if 'kesrouan' in city or 'kesrwane' in city:
        return 'Keserouan'
    if 'berbara' in city:
        return 'Berbara'

    return city_name.title()

df['city'] = df['city'].apply(standardize_city_names)

print("\nUnique cities after standardization:")
print(df['city'].value_counts().head(20))
print("\nDataFrame head after city standardization:")
df.head()
# Out:
# Unique cities before standardization:
# city
# El Batroun                                                                       207
# Keserouan                                                                        176
# Beirut                                                                           128
# Jbeil                                                                             62
# Apartment 200 sq. m in Mazraat Kfar Dibiane, Faqra, Mount Lebanon Governorate     39
# Aley                                                                              38
# Chouf                                                                             36
# Bcharre                                                                           27
# Apartment in Berbara, Keserwan‑Jbeil Governorate                                  24
# El Meten                                                                          20
# Apartment 80 sq. m in Armenia, Beirut, Beirut Governorate                         16
# Koura                                                                             15
# Batroun                                                                           14
# Apartment 19 sq. m in Gouraud, Beirut, Beirut Governorate                         12
# Apartment 50 sq. m in Armenia, Beirut, Beirut Governorate                         12
# House 60 sq. m in Berbara, Berbara, North Governorate                             12
# Zgharta                                                                           12
# Apartment 115 sq. m in Faraya, Mount Lebanon Governorate                          12
# House in Berbara, Mount Lebanon Governorate                                       12
# Apartment 72 sq. m in Armenia, Beirut, Beirut Governorate                         11
# Name: count, dtype: int64
#
# Unique cities after standardization:
# city
# Beirut                                                           320
# Batroun                                                          291
# Keserouan                                                        188
# Byblos                                                            97
# Faqra                                                             45
# Berbara                                                           41
# Aley                                                              38
# Chouf                                                             36
# Bcharre                                                           27
# El Meten                                                          20
# Koura                                                             15
# Apartment 115 Sq. M In Faraya, Mount Lebanon Governorate          12
# Zgharta                                                           12
# Zahle                                                              9
# El Nabatieh                                                        8
# Keserwan District                                                  8
# Mount Lebanon                                                      8
# Apartment 85 Sq. M In Faraya, Mount Lebanon Governorate            6
# Loft In 10 A Hortensia, Monteverde, Mount Lebanon Governorate      6
# Apartment 120 Sq. M In Faraya, Mount Lebanon Governorate           6
# Name: count, dtype: int64
#
# DataFrame head after city standardization:
#      platform                           title    city  bedrooms  bathrooms  \
# 99     airbnb             Apartment in Beirut  Beirut         1          1
# 1149  Stayinn  Amine 601, 1-BR in Mar Mikhael  Beirut         1          1
# 848   Stayinn  Amine 601, 1-BR in Mar Mikhael  Beirut         1          1
# 400   Stayinn  Amine 601, 1-BR in Mar Mikhael  Beirut         1          1
# 700   Stayinn  Amine 601, 1-BR in Mar Mikhael  Beirut         1          1
#
#       price  rating  review_count  amenities_count                last_scraped
# 99     35.0    4.75            99               37            19/11/2025 11:39
# 1149   92.0    5.00            98               43  2025-11-24T06:34:34.893310
# 848    91.0    5.00            98               43  2025-11-22T06:30:40.175210
# 400    94.0    5.00            98               43  2025-11-19T14:27:06.724146
# 700    93.0    5.00            98               43  2025-11-21T06:34:34.844513

# %%
df.to_csv('cleaned_scraping_project.csv', index=False)
print("DataFrame saved to 'cleaned_scraping_project.csv'")
# Out:
# DataFrame saved to 'cleaned_scraping_project.csv'
